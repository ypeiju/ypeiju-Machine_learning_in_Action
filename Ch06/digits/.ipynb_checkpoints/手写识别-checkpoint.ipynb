# %%
# -*-coding:utf-8 -*-
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline

# %%
class optStruct:
    """
    数据结构，维护所有需要操作的值
    Parameters：
        dataMatIn - 数据矩阵
        classLabels - 数据标签
        C - 松弛变量
        toler - 容错率
        kTup - 包含核函数信息的元组,第一个参数存放核函数类别，第二个参数存放必要的核函数需要用到的参数
    """
    def __init__(self, dataMatIn, classLabels, C, toler, kTup):
        self.X = dataMatIn                                #数据矩阵
        self.labelMat = classLabels                        #数据标签
        self.C = C                                         #松弛变量
        self.tol = toler                                 #容错率
        self.m = np.shape(dataMatIn)[0]                 #数据矩阵行数
        self.alphas = np.mat(np.zeros((self.m,1)))         #根据矩阵行数初始化alpha参数为0   
        self.b = 0                                         #初始化b参数为0
        self.eCache = np.mat(np.zeros((self.m,2)))         #根据矩阵行数初始化虎误差缓存，第一列为是否有效的标志位，第二列为实际的误差E的值。
        self.K = np.mat(np.zeros((self.m,self.m)))        #初始化核K
        for i in range(self.m):                            #计算所有数据的核K
            self.K[:,i] = kernelTrans(self.X, self.X[i,:], kTup)

# %%
def kernelTrans(X, A, kTup):
    """
    通过核函数将数据转换更高维的空间
    Parameters：
        X - 数据矩阵
        A - 单个数据的向量
        kTup - 包含核函数信息的元组
    Returns:
        K - 计算的核K
    """
    m,n = np.shape(X)
    K = np.mat(np.zeros((m,1)))
    if kTup[0] == 'lin': K = X * A.T                       #线性核函数,只进行内积。
    elif kTup[0] == 'rbf':                                 #高斯核函数,根据高斯核函数公式进行计算
        for j in range(m):
            deltaRow = X[j,:] - A
            K[j] = deltaRow*deltaRow.T
        K = np.exp(K/(-1*kTup[1]**2))                     #计算高斯核K
    else: raise NameError('核函数无法识别')
    return K                                             #返回计算的核K

# %%
def loadDataSet(fileName):
    """
    读取数据
    Parameters:
        fileName - 文件名
    Returns:
        dataMat - 数据矩阵
        labelMat - 数据标签
    """
    dataMat = []; labelMat = []
    fr = open(fileName)
    for line in fr.readlines():                                     #逐行读取，滤除空格等
        lineArr = line.strip().split('\t')
        dataMat.append([float(lineArr[0]), float(lineArr[1])])      #添加数据
        labelMat.append(float(lineArr[2]))                          #添加标签
    return dataMat,labelMat

# %%
def calcEk(oS, k):
    """
    计算误差
    Parameters：
        oS - 数据结构
        k - 标号为k的数据
    Returns:
        Ek - 标号为k的数据误差
    """
    fXk = float(np.multiply(oS.alphas,oS.labelMat).T*oS.K[:,k] + oS.b)
    Ek = fXk - float(oS.labelMat[k])
    return Ek

def selectJrand(i, m):
    """
    函数说明:随机选择alpha_j的索引值

    Parameters:
        i - alpha_i的索引值
        m - alpha参数个数
    Returns:
        j - alpha_j的索引值
    """
    j = i                                 #选择一个不等于i的j
    while (j == i):
        j = int(random.uniform(0, m))
    return j

def selectJ(i, oS, Ei):
    """
    内循环启发方式2
    Parameters：
        i - 标号为i的数据的索引值
        oS - 数据结构
        Ei - 标号为i的数据误差
    Returns:
        j, maxK - 标号为j或maxK的数据的索引值
        Ej - 标号为j的数据误差
    """
    maxK = -1; maxDeltaE = 0; Ej = 0                         #初始化
    oS.eCache[i] = [1,Ei]                                      #根据Ei更新误差缓存
    validEcacheList = np.nonzero(oS.eCache[:,0].A)[0]        #返回误差不为0的数据的索引值
    if (len(validEcacheList)) > 1:                            #有不为0的误差
        for k in validEcacheList:                           #遍历,找到最大的Ek
            if k == i: continue                             #不计算i,浪费时间
            Ek = calcEk(oS, k)                                #计算Ek
            deltaE = abs(Ei - Ek)                            #计算|Ei-Ek|
            if (deltaE > maxDeltaE):                        #找到maxDeltaE
                maxK = k; maxDeltaE = deltaE; Ej = Ek
        return maxK, Ej                                        #返回maxK,Ej
    else:                                                   #没有不为0的误差
        j = selectJrand(i, oS.m)                            #随机选择alpha_j的索引值
        Ej = calcEk(oS, j)                                    #计算Ej
    return j, Ej                                             #j,Ej

def updateEk(oS, k):
    """
    计算Ek,并更新误差缓存
    Parameters：
        oS - 数据结构
        k - 标号为k的数据的索引值
    Returns:
        无
    """
    Ek = calcEk(oS, k)                                        #计算Ek
    oS.eCache[k] = [1,Ek]                                    #更新误差缓存

def clipAlpha(aj,H,L):
    """
    修剪alpha_j
    Parameters:
        aj - alpha_j的值
        H - alpha上限
        L - alpha下限
    Returns:
        aj - 修剪后的alpah_j的值
    """
    if aj > H:
        aj = H
    if L > aj:
        aj = L
    return aj

# %%
def innerL(i, oS):
    """
    优化的SMO算法
    Parameters：
        i - 标号为i的数据的索引值
        oS - 数据结构
    Returns:
        1 - 有任意一对alpha值发生变化
        0 - 没有任意一对alpha值发生变化或变化太小
    """
    #步骤1：计算误差Ei
    Ei = calcEk(oS, i)
    #优化alpha,设定一定的容错率。
    if ((oS.labelMat[i] * Ei < -oS.tol) and (oS.alphas[i] < oS.C)) or ((oS.labelMat[i] * Ei > oS.tol) and (oS.alphas[i] > 0)):
        #使用内循环启发方式2选择alpha_j,并计算Ej
        j,Ej = selectJ(i, oS, Ei)
        #保存更新前的aplpha值，使用深拷贝
        alphaIold = oS.alphas[i].copy(); alphaJold = oS.alphas[j].copy();
        #步骤2：计算上下界L和H
        if (oS.labelMat[i] != oS.labelMat[j]):
            L = max(0, oS.alphas[j] - oS.alphas[i])
            H = min(oS.C, oS.C + oS.alphas[j] - oS.alphas[i])
        else:
            L = max(0, oS.alphas[j] + oS.alphas[i] - oS.C)
            H = min(oS.C, oS.alphas[j] + oS.alphas[i])
        if L == H:
            print("L==H")
            return 0
        #步骤3：计算eta
        eta = 2.0 * oS.K[i,j] - oS.K[i,i] - oS.K[j,j]
        if eta >= 0:
            print("eta>=0")
            return 0
        #步骤4：更新alpha_j
        oS.alphas[j] -= oS.labelMat[j] * (Ei - Ej)/eta
        #步骤5：修剪alpha_j
        oS.alphas[j] = clipAlpha(oS.alphas[j],H,L)
        #更新Ej至误差缓存
        updateEk(oS, j)
        if (abs(oS.alphas[j] - alphaJold) < 0.00001):
            print("alpha_j变化太小")
            return 0
        #步骤6：更新alpha_i
        oS.alphas[i] += oS.labelMat[j]*oS.labelMat[i]*(alphaJold - oS.alphas[j])
        #更新Ei至误差缓存
        updateEk(oS, i)
        #步骤7：更新b_1和b_2
        b1 = oS.b - Ei- oS.labelMat[i]*(oS.alphas[i]-alphaIold)*oS.K[i,i] - oS.labelMat[j]*(oS.alphas[j]-alphaJold)*oS.K[i,j]
        b2 = oS.b - Ej- oS.labelMat[i]*(oS.alphas[i]-alphaIold)*oS.K[i,j]- oS.labelMat[j]*(oS.alphas[j]-alphaJold)*oS.K[j,j]
        #步骤8：根据b_1和b_2更新b
        if (0 < oS.alphas[i]) and (oS.C > oS.alphas[i]): oS.b = b1
        elif (0 < oS.alphas[j]) and (oS.C > oS.alphas[j]): oS.b = b2
        else: oS.b = (b1 + b2)/2.0
        return 1
    else:
        return 0

# %%
def smoP(dataMatIn, classLabels, C, toler, maxIter, kTup = ('lin',0)):
    """
    完整的线性SMO算法
    Parameters：
        dataMatIn - 数据矩阵
        classLabels - 数据标签
        C - 松弛变量
        toler - 容错率
        maxIter - 最大迭代次数
        kTup - 包含核函数信息的元组
    Returns:
        oS.b - SMO算法计算的b
        oS.alphas - SMO算法计算的alphas
    """
    oS = optStruct(np.mat(dataMatIn), np.mat(classLabels).transpose(), C, toler, kTup)                #初始化数据结构
    iter = 0                                                                                         #初始化当前迭代次数
    entireSet = True; alphaPairsChanged = 0
    while (iter < maxIter) and ((alphaPairsChanged > 0) or (entireSet)):                            #遍历整个数据集都alpha也没有更新或者超过最大迭代次数,则退出循环
        alphaPairsChanged = 0
        if entireSet:                                                                                #遍历整个数据集                           
            for i in range(oS.m):       
                alphaPairsChanged += innerL(i,oS)                                                    #使用优化的SMO算法
                print("全样本遍历:第%d次迭代 样本:%d, alpha优化次数:%d" % (iter,i,alphaPairsChanged))
            iter += 1
        else:                                                                                         #遍历非边界值
            nonBoundIs = np.nonzero((oS.alphas.A > 0) * (oS.alphas.A < C))[0]                        #遍历不在边界0和C的alpha
            for i in nonBoundIs:
                alphaPairsChanged += innerL(i,oS)
                print("非边界遍历:第%d次迭代 样本:%d, alpha优化次数:%d" % (iter,i,alphaPairsChanged))
            iter += 1
        if entireSet:                                                                                #遍历一次后改为非边界遍历
            entireSet = False
        elif (alphaPairsChanged == 0):                                                                #如果alpha没有更新,计算全样本遍历
            entireSet = True 
        print("迭代次数: %d" % iter)
   # showSV(oS.X,oS.labelMat,oS.alphas)
    return oS.b,oS.alphas

# %%
def img2vector(filename):
    """
    将32x32的二进制图像转换为1x1024向量。
    Parameters:
        filename - 文件名
    Returns:
        returnVect - 返回的二进制图像的1x1024向量
    """
    returnVect = np.zeros((1,1024))
    fr = open(filename)
    for i in range(32):
        lineStr = fr.readline()
        for j in range(32):
            returnVect[0,32*i+j] = int(lineStr[j])
    return returnVect
def loadImages(dirName):
    """
    加载图片
    Parameters:
        dirName - 文件夹的名字
    Returns:
        trainingMat - 数据矩阵
        hwLabels - 数据标签
    """
    from os import listdir
    hwLabels = []
    trainingFileList = listdir(dirName)           
    m = len(trainingFileList)
    trainingMat = np.zeros((m,1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]     
        classNumStr = int(fileStr.split('_')[0])
        if classNumStr == 9: hwLabels.append(-1)
        else: hwLabels.append(1)
        trainingMat[i,:] = img2vector('%s/%s' % (dirName, fileNameStr))
    return trainingMat, hwLabels

# %%
def testDigits(kTup=('rbf', 10)):
    """
    测试函数
    Parameters:
        kTup - 包含核函数信息的元组
    Returns:
        无
    """
    dataArr,labelArr = loadImages('trainingDigits')
    b,alphas = smoP(dataArr, labelArr, 200, 0.0001, 10, kTup)
    datMat = np.mat(dataArr); labelMat = np.mat(labelArr).transpose()
    svInd = np.nonzero(alphas.A>0)[0]
    sVs=datMat[svInd]
    labelSV = labelMat[svInd];
    print("支持向量个数:%d" % np.shape(sVs)[0])
    m,n = np.shape(datMat)
    errorCount = 0
    for i in range(m):
        kernelEval = kernelTrans(sVs,datMat[i,:],kTup)
        predict=kernelEval.T * np.multiply(labelSV,alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]): errorCount += 1
    print("训练集错误率: %.2f%%" % (float(errorCount)/m))
    dataArr,labelArr = loadImages('testDigits')
    errorCount = 0
    datMat = np.mat(dataArr); labelMat = np.mat(labelArr).transpose()
    m,n = np.shape(datMat)
    for i in range(m):
        kernelEval = kernelTrans(sVs,datMat[i,:],kTup)
        predict=kernelEval.T * np.multiply(labelSV,alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]): errorCount += 1   
    print("测试集错误率: %.2f%%" % (float(errorCount)/m))

# %%
if __name__ == '__main__':
    testDigits()
# Out:
# 全样本遍历:第0次迭代 样本:0, alpha优化次数:1
# 全样本遍历:第0次迭代 样本:1, alpha优化次数:2
# 全样本遍历:第0次迭代 样本:2, alpha优化次数:3
# 全样本遍历:第0次迭代 样本:3, alpha优化次数:4
# 全样本遍历:第0次迭代 样本:4, alpha优化次数:5
# 全样本遍历:第0次迭代 样本:5, alpha优化次数:6
# 全样本遍历:第0次迭代 样本:6, alpha优化次数:6
# 全样本遍历:第0次迭代 样本:7, alpha优化次数:7
# 全样本遍历:第0次迭代 样本:8, alpha优化次数:8
# 全样本遍历:第0次迭代 样本:9, alpha优化次数:9
# 全样本遍历:第0次迭代 样本:10, alpha优化次数:10
# 全样本遍历:第0次迭代 样本:11, alpha优化次数:11
# 全样本遍历:第0次迭代 样本:12, alpha优化次数:12
# 全样本遍历:第0次迭代 样本:13, alpha优化次数:13
# 全样本遍历:第0次迭代 样本:14, alpha优化次数:14
# 全样本遍历:第0次迭代 样本:15, alpha优化次数:15
# 全样本遍历:第0次迭代 样本:16, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:17, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:18, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:19, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:20, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:21, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:22, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:23, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:24, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:25, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:26, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:27, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:28, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:29, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:30, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:31, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:32, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:33, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:34, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:35, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:36, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:37, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:38, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:39, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:40, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:41, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:42, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:43, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:44, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:45, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:46, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:47, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:48, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:49, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:50, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:51, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:52, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:53, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:54, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:55, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:56, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:57, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:58, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:59, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:60, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:61, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:62, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:63, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:64, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:65, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:66, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:67, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:68, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:69, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:70, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:71, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:72, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:73, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:74, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:75, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:76, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:77, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:78, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:79, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:80, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:81, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:82, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:83, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:84, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:85, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:86, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:87, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:88, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:89, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:90, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:91, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:92, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:93, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:94, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:95, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:96, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:97, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:98, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:99, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:100, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:101, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:102, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:103, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:104, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:105, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:106, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:107, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:108, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:109, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:110, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:111, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:112, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:113, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:114, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:115, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:116, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:117, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:118, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:119, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:120, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:121, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:122, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:123, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:124, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:125, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:126, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:127, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:128, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:129, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:130, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:131, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:132, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:133, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:134, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:135, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:136, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:137, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:138, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:139, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:140, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:141, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:142, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:143, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:144, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:145, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:146, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:147, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:148, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:149, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:150, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:151, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:152, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:153, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:154, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:155, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:156, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:157, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:158, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:159, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:160, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:161, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:162, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:163, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:164, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:165, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:166, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:167, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:168, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:169, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:170, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:171, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:172, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:173, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:174, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:175, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:176, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:177, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:178, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:179, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:180, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:181, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:182, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:183, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:184, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:185, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:186, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:187, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:188, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:189, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:190, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:191, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:192, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:193, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:194, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:195, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:196, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:197, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:198, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:199, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:200, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:201, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:202, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:203, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:204, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:205, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:206, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:207, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:208, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:209, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:210, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:211, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:212, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:213, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:214, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:215, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:216, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:217, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:218, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:219, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:220, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:221, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:222, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:223, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:224, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:225, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:226, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:227, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:228, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:229, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:230, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:231, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:232, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:233, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:234, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:235, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:236, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:237, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:238, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:239, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:240, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:241, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:242, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:243, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:244, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:245, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:246, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:247, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:248, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:249, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:250, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:251, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:252, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:253, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:254, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:255, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:256, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:257, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:258, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:259, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:260, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:261, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:262, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:263, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:264, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:265, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:266, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:267, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:268, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:269, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:270, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:271, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:272, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:273, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:274, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:275, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:276, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:277, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:278, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:279, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:280, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:281, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:282, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:283, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:284, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:285, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:286, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:287, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:288, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:289, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:290, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:291, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:292, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:293, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:294, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:295, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:296, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:297, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:298, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:299, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:300, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:301, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:302, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:303, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:304, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:305, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:306, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:307, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:308, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:309, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:310, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:311, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:312, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:313, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:314, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:315, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:316, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:317, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:318, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:319, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:320, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:321, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:322, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:323, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:324, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:325, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:326, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:327, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:328, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:329, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:330, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:331, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:332, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:333, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:334, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:335, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:336, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:337, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:338, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:339, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:340, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:341, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:342, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:343, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:344, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:345, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:346, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:347, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:348, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:349, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:350, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:351, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:352, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:353, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:354, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:355, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:356, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:357, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:358, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:359, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:360, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:361, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:362, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:363, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:364, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:365, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:366, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:367, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:368, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:369, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:370, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:371, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:372, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:373, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:374, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:375, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:376, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:377, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:378, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:379, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:380, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:381, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:382, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:383, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:384, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:385, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:386, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:387, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:388, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:389, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:390, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:391, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:392, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:393, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:394, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:395, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:396, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:397, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:398, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:399, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:400, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:401, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:402, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:403, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:404, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:405, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:406, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:407, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:408, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:409, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:410, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:411, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:412, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:413, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:414, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:415, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:416, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:417, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:418, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:419, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:420, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:421, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:422, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:423, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:424, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:425, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:426, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:427, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:428, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:429, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:430, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:431, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:432, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:433, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:434, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:435, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:436, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:437, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:438, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:439, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:440, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:441, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:442, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:443, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:444, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:445, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:446, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:447, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:448, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:449, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:450, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:451, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:452, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:453, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:454, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:455, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:456, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:457, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:458, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:459, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:460, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:461, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:462, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:463, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:464, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:465, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:466, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:467, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:468, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:469, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:470, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:471, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:472, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:473, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:474, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:475, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:476, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:477, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:478, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:479, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:480, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:481, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:482, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:483, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:484, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:485, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:486, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:487, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:488, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:489, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:490, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:491, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:492, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:493, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:494, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:495, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:496, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:497, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:498, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:499, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:500, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:501, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:502, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:503, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:504, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:505, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:506, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:507, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:508, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:509, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:510, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:511, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:512, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:513, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:514, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:515, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:516, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:517, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:518, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:519, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:520, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:521, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:522, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:523, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:524, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:525, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:526, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:527, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:528, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:529, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:530, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:531, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:532, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:533, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:534, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:535, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:536, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:537, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:538, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:539, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:540, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:541, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:542, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:543, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:544, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:545, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:546, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:547, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:548, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:549, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:550, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:551, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:552, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:553, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:554, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:555, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:556, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:557, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:558, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:559, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:560, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:561, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:562, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:563, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:564, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:565, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:566, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:567, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:568, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:569, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:570, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:571, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:572, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:573, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:574, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:575, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:576, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:577, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:578, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:579, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:580, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:581, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:582, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:583, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:584, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:585, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:586, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:587, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:588, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:589, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:590, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:591, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:592, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:593, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:594, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:595, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:596, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:597, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:598, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:599, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:600, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:601, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:602, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:603, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:604, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:605, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:606, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:607, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:608, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:609, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:610, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:611, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:612, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:613, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:614, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:615, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:616, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:617, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:618, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:619, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:620, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:621, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:622, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:623, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:624, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:625, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:626, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:627, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:628, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:629, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:630, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:631, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:632, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:633, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:634, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:635, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:636, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:637, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:638, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:639, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:640, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:641, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:642, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:643, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:644, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:645, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:646, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:647, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:648, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:649, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:650, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:651, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:652, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:653, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:654, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:655, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:656, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:657, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:658, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:659, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:660, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:661, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:662, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:663, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:664, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:665, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:666, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:667, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:668, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:669, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:670, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:671, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:672, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:673, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:674, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:675, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:676, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:677, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:678, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:679, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:680, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:681, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:682, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:683, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:684, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:685, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:686, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:687, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:688, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:689, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:690, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:691, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:692, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:693, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:694, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:695, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:696, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:697, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:698, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:699, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:700, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:701, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:702, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:703, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:704, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:705, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:706, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:707, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:708, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:709, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:710, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:711, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:712, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:713, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:714, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:715, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:716, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:717, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:718, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:719, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:720, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:721, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:722, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:723, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:724, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:725, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:726, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:727, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:728, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:729, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:730, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:731, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:732, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:733, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:734, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:735, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:736, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:737, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:738, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:739, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:740, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:741, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:742, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:743, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:744, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:745, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:746, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:747, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:748, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:749, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:750, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:751, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:752, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:753, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:754, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:755, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:756, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:757, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:758, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:759, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:760, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:761, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:762, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:763, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:764, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:765, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:766, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:767, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:768, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:769, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:770, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:771, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:772, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:773, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:774, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:775, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:776, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:777, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:778, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:779, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:780, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:781, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:782, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:783, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:784, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:785, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:786, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:787, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:788, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:789, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:790, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:791, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:792, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:793, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:794, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:795, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:796, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:797, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:798, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:799, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:800, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:801, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:802, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:803, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:804, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:805, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:806, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:807, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:808, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:809, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:810, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:811, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:812, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:813, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:814, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:815, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:816, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:817, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:818, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:819, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:820, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:821, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:822, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:823, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:824, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:825, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:826, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:827, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:828, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:829, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:830, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:831, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:832, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:833, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:834, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:835, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:836, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:837, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:838, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:839, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:840, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:841, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:842, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:843, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:844, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:845, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:846, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:847, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:848, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:849, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:850, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:851, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:852, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:853, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:854, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:855, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:856, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:857, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:858, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:859, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:860, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:861, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:862, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:863, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:864, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:865, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:866, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:867, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:868, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:869, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:870, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:871, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:872, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:873, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:874, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:875, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:876, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:877, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:878, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:879, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:880, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:881, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:882, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:883, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:884, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:885, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:886, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:887, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:888, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:889, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:890, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:891, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:892, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:893, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:894, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:895, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:896, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:897, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:898, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:899, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:900, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:901, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:902, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:903, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:904, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:905, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:906, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:907, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:908, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:909, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:910, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:911, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:912, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:913, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:914, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:915, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:916, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:917, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:918, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:919, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:920, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:921, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:922, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:923, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:924, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:925, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:926, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:927, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:928, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:929, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:930, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:931, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:932, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:933, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:934, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:935, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:936, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:937, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:938, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:939, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:940, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:941, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:942, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:943, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:944, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:945, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:946, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:947, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:948, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:949, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:950, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:951, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:952, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:953, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:954, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:955, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:956, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:957, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:958, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:959, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:960, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:961, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:962, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:963, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:964, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:965, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:966, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:967, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:968, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:969, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:970, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:971, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:972, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:973, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:974, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:975, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:976, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:977, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:978, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:979, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:980, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:981, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:982, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:983, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:984, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:985, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:986, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:987, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:988, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:989, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:990, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:991, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:992, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:993, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:994, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:995, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:996, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:997, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:998, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:999, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1000, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1001, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1002, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1003, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1004, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1005, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1006, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1007, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1008, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1009, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1010, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1011, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1012, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1013, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1014, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1015, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1016, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1017, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1018, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1019, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1020, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1021, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1022, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1023, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1024, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1025, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1026, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1027, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1028, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1029, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1030, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1031, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1032, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1033, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1034, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1035, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1036, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1037, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1038, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1039, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1040, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1041, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1042, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1043, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1044, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1045, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1046, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1047, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1048, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1049, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1050, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1051, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1052, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1053, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1054, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1055, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1056, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1057, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1058, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1059, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1060, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1061, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1062, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1063, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1064, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1065, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1066, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1067, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1068, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1069, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1070, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1071, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1072, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1073, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1074, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1075, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1076, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1077, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1078, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1079, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1080, alpha优化次数:16
# L==H
# 全样本遍历:第0次迭代 样本:1081, alpha优化次数:16
