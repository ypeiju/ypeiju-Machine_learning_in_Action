# %%
# %run notLinSeperable.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# E:\Python\jupyter\machinelearninginaction\Ch06\EXTRAS\notLinSeperable.py in <module>
#      11 markers =[]
#      12 colors =[]
# ---> 13 fr = open('testSet.txt')#this file was generated by 2normalGen.py
#      14 for line in fr.readlines():
#      15     lineSplit = line.strip().split('\t')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testSet.txt'
